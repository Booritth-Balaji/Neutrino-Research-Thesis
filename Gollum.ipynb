# %% [markdown]
# ## GollumFit

# %%
import GollumFitPy as gf

# %%
print(gf)
# Out:
# <module 'GollumFitPy' from '/home/peanuts/Projects/Neutrino-Research-Thesis/GollumFit/local/lib/python3.10/site-packages/GollumFitPy.cpython-310-x86_64-linux-gnu.so'>
