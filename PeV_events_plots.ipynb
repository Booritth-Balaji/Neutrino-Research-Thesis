# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy

# %%
# Importing atmospheric conv neutrino data from Honda et al. 2007 (https://arxiv.org/abs/astro-ph/0611418)
# contains both nu_mu and nu_e, with their bars 

data = pd.read_fwf('Data/PeV_neutrino_analysis/atm-conv/Honda-et-al-2007.d', sep = ' '  ,skiprows = 1)
data

# Importing the plots from Ranjan's paper fig 1
# data obtained from webplotdigitizer

r_conv_mu = pd.read_csv("Data/PeV_neutrino_analysis/Ranjan at al figs/fig 1/atm-conv_nu-mu.csv", header=None)
r_conv_e = pd.read_csv("Data/PeV_neutrino_analysis/Ranjan at al figs/fig 1/atm-conv_nu-e.csv", header=None)

# %%
# processing the data

E_conv = np.array(data['Enu(GeV)'])  # Conventional neutrino energy in GeV

nu_mu = np.array(data['NuMu']) * 1e-4  # cross section in (cm^2 sec sr GeV)^-1
nu_mu_bar = np.array(data['NuMubar']) * 1e-4 

nu_e = np.array(data['NuE']) * 1e-4   # cross section in (cm^2 sec sr GeV)^-1
nu_e_bar = np.array(data['NuEbar  (m^2']) * 1e-4 

nu_mu_conv = nu_mu + nu_mu_bar
nu_e_conv = nu_e + nu_e_bar

nu_mu_plot = nu_mu_conv * (E_conv**2)
nu_e_plot = nu_e_conv * (E_conv**2)

# %%
# Creating a extrapolate function

def extra(x, y, E): 

    # function is generated in the log scale to prevent negatives 
    # and for easier calculations
    extra_func = scipy.interpolate.interp1d(x=np.log(x), y = np.log(y), fill_value="extrapolate")

    # convert back into normal scale
    return np.exp(extra_func(np.log(E)))

# %%
# Plotting E^2 phi vs E 

plt.loglog(E_conv, nu_mu_plot, label = r"$\nu_\mu + \bar{\nu}_\mu$")
plt.loglog(E_conv, nu_e_plot, label = r"$\nu_e + \bar{\nu}_e$")
plt.xlabel(r"$E$ (GeV)")
plt.ylabel(r"$E^2 \phi$ (cm$^2$ sec sr GeV)$^(-1)$")
plt.title("Conventional neutrino flux spectrum")
plt.yticks(np.arange(1e-9, 1e-1, 1e5), labels=[])

# Extrapolating the data for higher energies
E_conv_ext = np.logspace(np.log10(E_conv[-1]), 7, num=1000)

plt.loglog(E_conv_ext, extra(E_conv, nu_mu_plot, E_conv_ext), 'm-.', label = r"Scipy extrapolated $\nu_\mu + \bar{\nu}_\mu$")
plt.loglog(E_conv_ext, extra(E_conv, nu_e_plot, E_conv_ext), 'c-.', label = r"Scipy extrapolated $\nu_e + \bar{\nu}_e$")

plt.legend()

# %%
# Importing the nu_mu(-) prompt neutrino flux data set 
# from: https://arxiv.org/pdf/0806.0418

prompt = pd.read_csv("Data/PeV_neutrino_analysis/atm-prompt/0806.0418-fig-10-prompt-nu_mu.csv", header=None)

E_prompt = 10**(np.array(prompt[0]))  # prompt neutrino energy in GeV 
E3phi = np.array(prompt[1])  # E^3 phi in GeV^2 (cm^2 sec sr)^-1

E2phi = E3phi/(E_prompt)   # E^2 phi in GeV (cm^2 sec sr)^-1

atm_prompt = E2phi / (E_prompt)**2  # prompt neutrino flux in (cm^2 sec sr GeV)^-1


# Importing data from Ranjan et al fig 1 for prompt nu_mu

r_prompt = pd.read_csv("Data/PeV_neutrino_analysis/Ranjan at al figs/fig 1/atm-prompt.csv", header=None)

# %%
# Recreating figure 1 from Ranjan et al. 

# conventional neutrinos
plt.loglog(E_conv, nu_mu_plot, label = r"conventional $\nu_\mu + \bar{\nu}_\mu$")
plt.loglog(E_conv, nu_e_plot, label = r"conventional $\nu_e + \bar{\nu}_e$")
plt.xlabel(r"$E$ (GeV)")
plt.ylabel(r"$E^2 \phi$ (cm$^2$ sec sr GeV)$^(-1)$")
plt.yticks(np.arange(1e-9, 1e-1, 1e5), labels=[])

# extrapolated lines
plt.loglog(E_conv_ext, extra(E_conv, nu_mu_plot, E_conv_ext), 'r:', label = r"Extrapolated $\nu_\mu + \bar{\nu}_\mu$")
plt.loglog(E_conv_ext, extra(E_conv, nu_e_plot, E_conv_ext), 'g:', label = r"Extrapolated $\nu_e + \bar{\nu}_e$")

# prompt neutrinos
plt.loglog(E_prompt, E2phi, label=r"prompt $\nu_\mu + \bar{\nu}_\mu$")
plt.xlabel(r"$E$ (GeV)")
plt.ylabel(r"$E^2 \phi$ (GeV cm$^{-2}$ sec$^{-1}$ sr$^{-1}$)")
plt.title("Neutrino fluxes")

plt.xlim(1e4, 1e10)
plt.ylim(1e-10, 1e-7)
plt.legend()
plt.show()

# %%
# Importing atmospherical conventional neutrino data from https://arxiv.org/pdf/1212.4760

# nu_e data from fig 4 of https://arxiv.org/pdf/1212.4760
nu_e_conv_1212 = pd.read_csv("Data/PeV_neutrino_analysis/atm-conv/1212.4760_fig-4_nu-e.csv", header=None)

# nu_e error bars 
nu_e_y_min = pd.read_csv("Data/PeV_neutrino_analysis/atm-conv/1212.4760_fig-4_nu-e_errors/y_err-min.csv", header=None)
nu_e_y_max = pd.read_csv("Data/PeV_neutrino_analysis/atm-conv/1212.4760_fig-4_nu-e_errors/y_err-max.csv", header=None)
nu_e_x_min = pd.read_csv("Data/PeV_neutrino_analysis/atm-conv/1212.4760_fig-4_nu-e_errors/x_err-min.csv", header=None)
nu_e_x_max = pd.read_csv("Data/PeV_neutrino_analysis/atm-conv/1212.4760_fig-4_nu-e_errors/x_err-max.csv", header=None)

# nu_mu data from fig 23 of https://arxiv.org/pdf/1010.3980
nu_mu_conv_1010 = pd.read_csv("Data/PeV_neutrino_analysis/atm-conv/1010.3980_fig-23_nu-mu.csv", header=None)

# nu_mu error bars
nu_mu_y_min = pd.read_csv("Data/PeV_neutrino_analysis/atm-conv/1010.3980_fig-23_nu-mu_errors/y_err-min(1).csv", header=None)
nu_mu_y_max = pd.read_csv("Data/PeV_neutrino_analysis/atm-conv/1010.3980_fig-23_nu-mu_errors/y_err-max(1).csv", header=None)
nu_mu_x_min = pd.read_csv("Data/PeV_neutrino_analysis/atm-conv/1010.3980_fig-23_nu-mu_errors/x_err-min(1).csv", header=None)
nu_mu_x_max = pd.read_csv("Data/PeV_neutrino_analysis/atm-conv/1010.3980_fig-23_nu-mu_errors/x_err-max(1).csv", header=None)

logE_conv_e_1212 = np.array(nu_e_conv_1212[0])  # in log(GeV)
E_conv_e_1212 = 10**logE_conv_e_1212  # in GeV
logE_conv_mu_1010 = np.array(nu_mu_conv_1010[0])  # in log(GeV)
E_conv_mu_1010 = 10**logE_conv_mu_1010  # in GeV
E2phi_e_1212 = np.array(nu_e_conv_1212[1])  # in GeV cm^-2 sec^-1 sr^-1
E2phi_mu_1010 = np.array(nu_mu_conv_1010[1])  # in GeV cm^-2 sec^-1 sr^-1

E2phi_mu_1010 = E2phi_mu_1010[np.argsort(E_conv_mu_1010)]
E_conv_mu_1010 = np.sort(E_conv_mu_1010)

# Importing the reference data from Ranjan et al fig 2 

nu_fig_2 = pd.read_csv("Data/PeV_neutrino_analysis/Ranjan at al figs/fig 2/atm-nu.csv", header=None)
E_2_fig_2 = pd.read_csv("Data/PeV_neutrino_analysis/Ranjan at al figs/fig 2/E-2.csv", header=None)
E_2_5_fig_2 = pd.read_csv("Data/PeV_neutrino_analysis/Ranjan at al figs/fig 2/E-2.5.csv", header=None)
E_3_fig_2 = pd.read_csv("Data/PeV_neutrino_analysis/Ranjan at al figs/fig 2/E-3.csv", header=None)

# %%
# Recreating figure 2 from Ranjan et al. 

# Plotting the conventional neutrino fluxes data from 1212.4760 and 1010.3980

plt.errorbar(E_conv_mu_1010, E2phi_mu_1010, xerr=[E_conv_mu_1010 - 10**np.array(nu_mu_x_min[0]), 10**np.array(nu_mu_x_max[0]) - E_conv_mu_1010], yerr=[E2phi_mu_1010 - np.array(nu_mu_y_min[1]), np.array(nu_mu_y_max[1]) - E2phi_mu_1010], fmt='o' , label=r"$\nu_\mu + \bar{\nu}_\mu$")
plt.errorbar(E_conv_e_1212, E2phi_e_1212, xerr=[E_conv_e_1212 - 10**np.array(nu_e_x_min[0]), 10**np.array(nu_e_x_max[0]) - E_conv_e_1212], yerr=[E2phi_e_1212 - np.array(nu_e_y_min[1]), np.array(nu_e_y_max[1]) - E2phi_e_1212], fmt='yo' ,label=r"$\nu_e + \bar{\nu}_e$")

plt.xscale('log')
plt.yscale('log')


# Setting the normalization for the spectra

pivot = 7e-9 
plt.axhline(y = pivot, color='r', linestyle='--', label=r'$E^{-2}$')

c_05 = pivot / (E_conv_mu_1010[np.argmin(E2phi_mu_1010)])**(-0.5)
plt.plot(E_conv_mu_1010, (E_conv_mu_1010 )**(-0.5) * c_05,'-.' , label=r'$E^{-2.5}$')

c_10 = pivot / (E_conv_mu_1010[np.argmin(E2phi_mu_1010)])**(-1)
plt.plot(E_conv_mu_1010, (E_conv_mu_1010 )**(-1) * c_10, ':',label=r'$E^{-3}$')


# Reference lines from Ranjan et al fig 2

# plt.plot(E_2_fig_2[0], E_2_fig_2[1], label=r"$E^{-2}$ reference line", linestyle='--')
# plt.plot(E_2_5_fig_2[0], E_2_5_fig_2[1], label=r"$E^{-2.5}$ reference line", linestyle='--')
# plt.plot(E_3_fig_2[0], E_3_fig_2[1], label=r"$E^{-3}$ reference line", linestyle='--')
# plt.plot(E_prompt, E2phi, label=r"prompt $\nu_\mu + \bar{\nu}_\mu$ from 0806.0418")

plt.xlabel(r"$E$ (GeV)")
plt.ylabel(r"$E^2 {d\phi}/{dE}$ (GeV cm$^{-2}$ sec$^{-1}$ sr$^{-1}$)")
plt.xlim(10**2.2, 1e6)
plt.ylim(1e-10, 1e-3)
plt.title("Normalizing the power law fluxes")
plt.legend()
plt.show()

# %%
# Plotting all the fluxes together

x = np.logspace(2, 7, num=1000)

plt.loglog(x,  x**(0) * pivot, label=r'$E^{-2}$')
plt.loglog(x, (x)**(-0.5) * c_05, label=r'$E^{-2.5}$')
plt.loglog(x, (x)**(-1) * c_10, label=r'$E^{-3}$')
plt.loglog(x, extra(E_conv, nu_mu_plot, x), 'b:', label = r"conv. $\nu_\mu + \bar{\nu}_\mu$")
plt.loglog(x, extra(E_conv, nu_e_plot, x), 'g:', label = r"conv. $\nu_e + \bar{\nu}_e$")
plt.loglog(E_prompt, E2phi, 'k--',label=r"prompt")

plt.xlabel(r"$E$ (GeV)")
plt.ylabel(r"$E^2 {d\phi}/{dE}$ (GeV cm$^{-2}$ sec$^{-1}$ sr$^{-1}$)")
plt.title("Neutrino fluxes")
plt.xlim(1e4, 1e7)
plt.ylim(1e-10, 1e-6)
plt.legend()

# %% [markdown]
# ---
#
# ### Realistic case of fig 3
#
# $$ \frac{dN}{dE} = 4 \pi \cdot A_{eff} \cdot T \cdot \frac{d \phi}{d E} $$

# %%
# Importing data for recreating fig 3 


# Effective area data from fig 3 of https://arxiv.org/pdf/1304.5356
A_eff_e = pd.read_csv("Data/PeV_neutrino_analysis/effective-area/1304.5356_fig-3_nu-e.csv", header=None)
A_eff_mu = pd.read_csv("Data/PeV_neutrino_analysis/effective-area/1304.5356_fig-3_nu-mu.csv", header=None)

E_casc_e = 10**(np.array(A_eff_e[0]))  # in GeV
A_eff_e_casc = np.array(A_eff_e[1]) * 10000  # in cm^2


# Importing reference lines for fig 3 from Ranjan et al fig 3 - realistic

E_2_fig_3 = pd.read_csv("Data/PeV_neutrino_analysis/Ranjan at al figs/fig 3/realistic/E-2.csv", header=None)
E_2_5_fig_3 = pd.read_csv("Data/PeV_neutrino_analysis/Ranjan at al figs/fig 3/realistic/E-2.5.csv", header=None)
E_3_fig_3 = pd.read_csv("Data/PeV_neutrino_analysis/Ranjan at al figs/fig 3/realistic/E-3.csv", header=None)
E_conv_fig_3 = pd.read_csv("Data/PeV_neutrino_analysis/Ranjan at al figs/fig 3/realistic/atm-conv.csv", header=None)
E_prompt_fig_3 = pd.read_csv("Data/PeV_neutrino_analysis/Ranjan at al figs/fig 3/realistic/atm-prompt.csv", header=None)

# %%
# Making a convolution function 

# First defining the gaussian
def gaussian(x, mu, sigma):
    return (1/(sigma * np.sqrt(2 * np.pi))) * np.exp(-0.5 * ((x - mu)/sigma)**2)

# Then defining the convolution function
def convolve(x, y, sigma_percent):

    sigma = sigma_percent * x

    dx = np.diff(x)
    for i in range(len(dx)):
        if dx[i] <= 0:
            dx[i] = dx[i-1]
    dx = np.append(dx, dx[-1])

    y_conv = np.zeros(len(x))

    for i in range(len(x)):
        mu = x[i]
        g = gaussian(x, mu, sigma[i])
        y_conv += y[i] * g * dx[i]

    return y_conv

# %%
# Plotting the realistic case neutrino spectra 

T = 615.9 * 24 * 3600  # exposure time in seconds (615.9 days)

# Plotting the convolved spectra

plt.loglog(E_casc_e, convolve(E_casc_e, E_casc_e * 4 * np.pi * A_eff_e_casc * T * pivot * E_casc_e**(-2), 0.15), label=r"$E^{-2}$", color='r', linestyle='-')
plt.loglog(E_casc_e, convolve(E_casc_e, E_casc_e * 4 * np.pi * A_eff_e_casc * T * c_05 * E_casc_e**(-2.5), 0.15), label=r"$E^{-2.5}$", color='b', linestyle='--')
plt.loglog(E_casc_e, convolve(E_casc_e, E_casc_e * 4 * np.pi * A_eff_e_casc * T * c_10 * E_casc_e**(-3), 0.15), label=r"$E^{-3.0}$", color='g', linestyle='-.')
plt.loglog(E_casc_e, convolve(E_casc_e, E_casc_e * 4 * np.pi * A_eff_e_casc * T * extra(E_prompt, atm_prompt, E_casc_e), 0.15), label="Atm. prompt", color='c', linestyle=':')
plt.loglog(E_casc_e, convolve(E_casc_e, E_casc_e * 4 * np.pi * A_eff_e_casc * T * extra(E_conv, nu_e_conv, E_casc_e), 0.15), label="Atm. conv", color='m')


# Plotting the reference lines from Ranjan et al fig 3

# plt.loglog(E_2_fig_3[0][:-2], E_2_fig_3[1][:-2], label=r"$E^{-2}$ reference line", linestyle='--', color='r')
# plt.loglog(E_2_5_fig_3[0][:-2], E_2_5_fig_3[1][:-2], label=r"$E^{-2.5}$ reference line", linestyle='--', color='g')
# plt.loglog(E_3_fig_3[0][:-2], E_3_fig_3[1][:-2], label=r"$E^{-3}$ reference line", linestyle='--', color='b')
# plt.loglog(E_conv_fig_3[0][:-2], E_conv_fig_3[1][:-2], label="Atm. conv reference line", linestyle='--', color='m')
# plt.loglog(E_prompt_fig_3[0], E_prompt_fig_3[1], label="Atm. prompt reference line", linestyle='--', color='c')


plt.xlabel("Energy (GeV)")
plt.ylabel("E dN/dE")
plt.title(r"Realistic (CC + NC) $\nu_e + \bar{\nu}_e$ spectra")
plt.legend(loc='lower left')
plt.xlim(1e6, 1e7)
plt.ylim(1e-4, 1e1)
plt.show()

# %% [markdown]
# ---
#
# ### Ideal case of fig 3
#
# $$ \frac{dN}{dE_{\rm casc}}
# \simeq 2\pi \, \rho \, N_A \, V \, T
# \int_{-1}^{+1} d(\cos\theta_z)\,
# \frac{d\Phi}{dE_\nu}(E_\nu)\,
# \sigma(E_\nu)\,
# e^{-\tau(E_\nu,\cos\theta_z)} \, $$
#
# After solving the integral, we get the following:
#
# $$ \frac{dN}{dE_{\rm casc}}
# \simeq 2\pi \, \rho \, N_A \, V \, T \frac{d\Phi}{dE_\nu}(E_\nu)\,
# \sigma(E_\nu)\, \cdot \left[ \frac{1}{2Rn \sigma} \left( 1 - \frac{1}{e^{2Rn \sigma}} \right) + 1 \right] $$

# %%
# Importing Ranjan et al fig 3 for ideal case comparison

ideal_df = pd.read_csv("Data/PeV_neutrino_analysis/Ranjan at al figs/fig 3/ideal/atm conv, E-2, E-2.5, E-3.csv") 

E_E2_ideal = np.array([float(item) for item in ideal_df.iloc[1:-3, 0]])[np.argsort(np.array([float(item) for item in ideal_df.iloc[1:-3, 0]]))]
EdNdE_E2_ideal = np.array([float(item) for item in ideal_df.iloc[1:-3, 1]])[np.argsort(np.array([float(item) for item in ideal_df.iloc[1:-3, 0]]))]

E_E25_ideal = np.array([float(item) for item in ideal_df.iloc[1:-3, 2]])[np.argsort(np.array([float(item) for item in ideal_df.iloc[1:-3, 2]]))]   
EdNdE_E25_ideal = np.array([float(item) for item in ideal_df.iloc[1:-3, 3]])[np.argsort(np.array([float(item) for item in ideal_df.iloc[1:-3, 2]]))]

E_E3_ideal = np.array([float(item) for item in ideal_df.iloc[1:-3, 4]])[np.argsort(np.array([float(item) for item in ideal_df.iloc[1:-3, 4]]))]
EdNdE_E3_ideal = np.array([float(item) for item in ideal_df.iloc[1:-3, 5]])[np.argsort(np.array([float(item) for item in ideal_df.iloc[1:-3, 4]]))]

E_prompt_ideal = np.array([float(item) for item in ideal_df.iloc[1:-2, 6]])[np.argsort(np.array([float(item) for item in ideal_df.iloc[1:-2, 6]]))]
EdNdE_prompt_ideal = np.array([float(item) for item in ideal_df.iloc[1:-2, 7]])[np.argsort(np.array([float(item) for item in ideal_df.iloc[1:-2, 6]]))]

E_conv_ideal = np.array([float(item) for item in ideal_df.iloc[1:, 8]])[np.argsort(np.array([float(item) for item in ideal_df.iloc[1:, 8]]))]
EdNdE_conv_ideal = np.array([float(item) for item in ideal_df.iloc[1:, 9]])[np.argsort(np.array([float(item) for item in ideal_df.iloc[1:, 8]]))]

E_prompt_ideal = np.array(pd.read_csv("Data/PeV_neutrino_analysis/Ranjan at al figs/fig 3/ideal/atm prompt.csv", header=None)[0])  # in GeV
EdNdE_prompt_ideal = np.array(pd.read_csv("Data/PeV_neutrino_analysis/Ranjan at al figs/fig 3/ideal/atm prompt.csv", header=None)[1])  # in GeV

# %%
# Setting up parameters 

rho_ice = 0.917 # g/cm^3
N_A = 6.022e23  # Avogadro's number
V_ice = 1e15   # 1km^3 in cm^3
T = 615.9 * 24 * 3600  # exposure time in seconds (615.9 days) 
R = 6371e5  # Earth's radius in cm
n = 1.79e24  # number density of the earth in cm^-3
y = 0.25  # inelasticity parameter


# Importing the cross sections

sigma_nu = pd.read_csv("Data/PeV_neutrino_analysis/cross-sections/nu_cross_section.csv")
sigma_nu_bar = pd.read_csv("Data/PeV_neutrino_analysis/cross-sections/nu_bar_cross_section.csv")


# Generating functions for sigma_CC and sigma_NC for both nu and nu_bar

sigma_CC_nu_func = scipy.interpolate.interp1d(sigma_nu['E_nu [GeV]'], sigma_nu['sigma_CC [cm2]'])
sigma_NC_nu_func = scipy.interpolate.interp1d(sigma_nu['E_nu [GeV]'], sigma_nu['sigma_NC [cm2]'])
sigma_CC_nu_bar_func = scipy.interpolate.interp1d(sigma_nu_bar['E_nu [GeV]'], sigma_nu_bar['sigma_CC [cm2]'])
sigma_NC_nu_bar_func = scipy.interpolate.interp1d(sigma_nu_bar['E_nu [GeV]'], sigma_nu_bar['sigma_NC [cm2]'])  


# Generating the energy array

E_casc = np.linspace(10**3.45, 10**9.55, 10000)


# Adding the glashow resonance at 6.3 PeV

E_casc = np.append(E_casc, 6.3e6)
E_casc = np.sort(E_casc)

sigma_CC_nu = sigma_CC_nu_func(E_casc)
sigma_CC_nu_bar = sigma_CC_nu_bar_func(E_casc)


# Setting the cross section at the glashow resonance to be 350 times higher than the actual value

sigma_CC_nu_bar[np.argwhere(E_casc == 6.3e6)] = 350 * sigma_CC_nu_bar_func(6.3e6)  


# For NC interactions, E_casc = y * E_nu, so we need to calculate the cross section at E_casc/y

E_casc_NC = E_casc / y
sigma_NC_nu = sigma_NC_nu_func(E_casc_NC)
sigma_NC_nu_bar = sigma_NC_nu_bar_func(E_casc_NC)

# %%
# Defining a function to calculate the integrated value

def integrand(sigma): 

    fac = 2 * R * n * sigma

    return (1/fac) * (1 - np.exp(-fac)) + 1


# Defining a function to calculate the number of events for the cascades

def dNdE_casc(flux, sigma): 
    return 2 * np.pi * rho_ice * N_A * V_ice * T * flux * sigma * integrand(sigma)

# %%
# Plotting the convolved spectra for the ideal case

plt.loglog(E_casc, convolve(E_casc, E_casc * dNdE_casc(pivot * (E_casc)**(-2) / 2, sigma_CC_nu) + E_casc * dNdE_casc(pivot * (E_casc)**(-2) / 2, sigma_CC_nu_bar) + E_casc * (1/y) * dNdE_casc(pivot * (E_casc_NC)**(-2) / 2, sigma_NC_nu) + E_casc * (1/y) * dNdE_casc(pivot * (E_casc_NC)**(-2) / 2, sigma_NC_nu_bar), 0.15), label=r"$E^{-2}$", color='r', linestyle='-')

plt.loglog(E_casc, convolve(E_casc, E_casc * dNdE_casc(c_05 * (E_casc)**(-2.5) / 2, sigma_CC_nu) + E_casc * dNdE_casc(c_05 * (E_casc)**(-2.5) / 2, sigma_CC_nu_bar) + E_casc * (1/y) * dNdE_casc(c_05 * (E_casc_NC)**(-2.5) / 2, sigma_NC_nu) + E_casc * (1/y) * dNdE_casc(c_05 * (E_casc_NC)**(-2.5) / 2, sigma_NC_nu_bar), 0.15), label=r"$E^{-2.5}$", color='b', linestyle='--')

plt.loglog(E_casc, convolve(E_casc, E_casc * dNdE_casc(c_10 * (E_casc)**(-3) / 2, sigma_CC_nu) + E_casc * dNdE_casc(c_10 * (E_casc)**(-3) / 2, sigma_CC_nu_bar), 0.15) + E_casc * (1/y) * dNdE_casc(c_10 * (E_casc_NC)**(-3) / 2, sigma_NC_nu) + E_casc * (1/y) * dNdE_casc(c_10 * (E_casc_NC)**(-3) / 2, sigma_NC_nu_bar), label=r"$E^{-3}$", color='g', linestyle='-.')

plt.loglog(E_casc, convolve(E_casc, E_casc * dNdE_casc(extra(E_prompt, atm_prompt, E_casc) / 2, sigma_CC_nu) + E_casc * dNdE_casc(extra(E_prompt, atm_prompt, E_casc) / 2, sigma_CC_nu_bar) + E_casc * (1/y) * dNdE_casc(extra(E_prompt, atm_prompt, E_casc_NC) / 2, sigma_NC_nu) + E_casc * (1/y) * dNdE_casc(extra(E_prompt, atm_prompt, E_casc_NC) / 2, sigma_NC_nu_bar), 0.15), label="Atm. prompt", color='c', linestyle=':')

plt.loglog(E_casc, convolve(E_casc, E_casc * dNdE_casc(extra(E_conv, nu_e, E_casc), sigma_CC_nu) + E_casc * dNdE_casc(extra(E_conv, nu_e_bar, E_casc), sigma_CC_nu_bar) + E_casc * (1/y) * dNdE_casc(extra(E_conv, nu_e, E_casc_NC), sigma_NC_nu) + E_casc * (1/y) * dNdE_casc(extra(E_conv, nu_e_bar, E_casc_NC), sigma_NC_nu_bar), 0.15), label="Atm. conv", color='m')


# Plotting the reference lines from Ranjan et al fig 3

# plt.loglog(E_E2_ideal, EdNdE_E2_ideal, '--', color='r')
# plt.loglog(E_E25_ideal, EdNdE_E25_ideal, '--', color='b')
# plt.loglog(E_E3_ideal, EdNdE_E3_ideal, '--', color='g')
# plt.loglog(E_prompt_ideal, EdNdE_prompt_ideal, '--', color='c')
# plt.loglog(E_conv_ideal, EdNdE_conv_ideal, '--', color='m')

plt.xlabel("Energy (GeV)")
plt.ylabel("E dN/dE")
plt.title(r"Theoretical (CC + NC) $\nu_e + \bar{\nu}_e$ spectra")
plt.xlim(1e6, 1e7)
plt.ylim(1e-4, 1e1)
plt.legend(loc='lower left')
plt.show()

# %% [markdown]
# ---
#
# ### Creating Table 1

# %%
# Integrating the convolved spectra to get the number of events 
# in the 1-2 PeV and 2-10 PeV bins for both the realistic and ideal cases

y = np.array([
    pivot * E_casc_e**(-2), 
    c_05 * E_casc_e**(-2.5), 
    c_10 * E_casc_e**(-3), 
    extra(E_conv, nu_e_conv, E_casc_e), 
    extra(E_prompt, atm_prompt, E_casc_e)])

x = E_casc_e

for i in range(len(y)):
    y_conv = convolve(E_casc_e, E_casc_e * 4 * np.pi * A_eff_e_casc * T * y[i], 0.15)
    
    # Bin 1-2 PeV
    x_1 = np.log(x[(x >= 1e6) & (x < 2e6)])
    y_1 = y_conv[(x >= 1e6) & (x < 2e6)]
    events_1 = np.trapezoid(y_1, x_1)
    print(f"Number of events in 1-2 PeV for spectrum {i}: {events_1}")

    # Bin 2-10 PeV
    x_2 = np.log(x[(x >= 2e6) & (x < 1e7)])
    y_2 = y_conv[(x >= 2e6  ) & (x < 1e7)]
    events_2 = np.trapezoid(y_2, x_2)
    print(f"Number of events in 2-10 PeV for spectrum {i}: {events_2}")
# Out:
# Number of events in 1-2 PeV for spectrum 0: 0.14876524578700184
# Number of events in 2-10 PeV for spectrum 0: 1.6897613045281246
# Number of events in 1-2 PeV for spectrum 1: 0.06612968717468717
# Number of events in 2-10 PeV for spectrum 1: 0.3792916618701863
# Number of events in 1-2 PeV for spectrum 2: 0.029772732484646902
# Number of events in 2-10 PeV for spectrum 2: 0.08738970426838952
# Number of events in 1-2 PeV for spectrum 3: 0.0003567221394062929
# Number of events in 2-10 PeV for spectrum 3: 0.00045347353921732154
# Number of events in 1-2 PeV for spectrum 4: 0.012572627968228533
# Number of events in 2-10 PeV for spectrum 4: 0.0355527173569868

# %%
# Recreating table 1 but for the ideal case as well

y = np.array([
    pivot * E_casc**(-2), 
    c_05 * E_casc**(-2.5), 
    c_10 * E_casc**(-3), 
    extra(E_conv, nu_e_conv, E_casc), 
    extra(E_prompt, atm_prompt, E_casc)])

x = E_casc

for i in range(len(y)):
    y_conv = convolve(E_casc, E_casc * dNdE_casc(y[i] / 2, sigma_CC_nu) + E_casc * dNdE_casc(y[i] / 2, sigma_CC_nu_bar) + E_casc * (1/y[i]) * dNdE_casc(y[i] / 2, sigma_NC_nu) + E_casc * (1/y[i]) * dNdE_casc(y[i] / 2, sigma_NC_nu_bar), 0.15)
    
    # Bin 1-2 PeV
    x_1 = np.log(x[(x >= 1e6) & (x < 2e6)])
    y_1 = y_conv[(x >= 1e6) & (x < 2e6)]
    events_1 = np.trapezoid(y_1, x_1)
    print(f"Number of events in 1-2 PeV for spectrum {i}: {events_1}")

    # Bin 2-10 PeV
    x_2 = np.log(x[(x >= 2e6) & (x < 1e7)])
    y_2 = y_conv[(x >= 2e6  ) & (x < 1e7)]
    events_2 = np.trapezoid(y_2, x_2)
    print(f"Number of events in 2-10 PeV for spectrum {i}: {events_2}")
# Out:
# Number of events in 1-2 PeV for spectrum 0: 1.3141726860167537e+20
# Number of events in 2-10 PeV for spectrum 0: 2.2883536101735106e+21
# Number of events in 1-2 PeV for spectrum 1: 1.3141726860167537e+20
# Number of events in 2-10 PeV for spectrum 1: 2.2883536101735106e+21
# Number of events in 1-2 PeV for spectrum 2: 1.3141726860167537e+20
# Number of events in 2-10 PeV for spectrum 2: 2.2883536101735106e+21
# Number of events in 1-2 PeV for spectrum 3: 1.3141726860167537e+20
# Number of events in 2-10 PeV for spectrum 3: 2.2883536101735106e+21
# Number of events in 1-2 PeV for spectrum 4: 1.3141726860167537e+20
# Number of events in 2-10 PeV for spectrum 4: 2.2883536101735106e+21
